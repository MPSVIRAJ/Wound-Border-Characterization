# %% [markdown]
# ## Processing wound images rectifies wound borders,extracts geometric features from depth, and prepares for clustering.

# %%
# --- Imports ---
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter1d
from scipy.stats import skew, kurtosis
from scipy.fft import fft
from scipy.integrate import simpson
from skimage.measure import find_contours
from scipy.ndimage import map_coordinates, gaussian_filter

# --- Load Input Files ---
def load_inputs(name: str, base_path: str):
    img = cv2.imread(f"{base_path}/images/{name}.png")[..., ::-1]
    depth = cv2.imread(f"{base_path}/depth_maps/{name}.png", cv2.IMREAD_ANYDEPTH)
    wound = cv2.imread(f"{base_path}/wound_masks/{name}.png", cv2.IMREAD_GRAYSCALE)
    body = cv2.imread(f"{base_path}/body_masks/{name}.png", cv2.IMREAD_GRAYSCALE)

    # Safe check: Load marker only if exists
    marker_path = f"{base_path}/marker_masks/{name}.png"
    marker = cv2.imread(marker_path, cv2.IMREAD_GRAYSCALE) if os.path.exists(marker_path) else None

    # Apply masks
    depth = cv2.bitwise_and(depth, depth, mask=body)
    if marker is not None:
        depth = cv2.bitwise_and(depth, depth, mask=~marker)
        body = cv2.bitwise_and(body, body, mask=~marker)

    return img, depth, wound, body

# --- Z-score Filtering ---
def filter_body_with_zscore(depth, body):
    z_score = (depth - depth.mean()) / depth.std()
    body_corrected = body.copy()
    body_corrected[(z_score < -2) | (z_score > 2)] = 0
    return body_corrected, cv2.bitwise_and(depth, depth, mask=body_corrected)

# --- Surface Fitting ---
def quad_surface(xy, a, b, c, d, e, f):
    x, y = xy
    return a + b*x + c*y + d*x**2 + e*y**2 + f*x*y

def correct_depth_curvature(depth_component, wound, body_corrected):
    margin = 40
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    wound_dilated = cv2.dilate(wound, kernel, iterations=margin)
    wound_eroded = cv2.erode(wound, kernel, iterations=margin)
    peri_lesion_mask = cv2.bitwise_xor(wound_dilated, wound_eroded)
    peri_lesion_mask = cv2.bitwise_and(peri_lesion_mask, peri_lesion_mask, mask=body_corrected)

    coords_y, coords_x = np.where(peri_lesion_mask > 0)
    
    if len(coords_x) == 0 or len(coords_y) == 0:
        raise ValueError("Peri-lesion mask is empty, skipping curve fitting.")
    
    z_vals = depth_component[coords_y, coords_x]
    params, _ = curve_fit(quad_surface, (coords_x, coords_y), z_vals)

    h, w = depth_component.shape
    grid_y, grid_x = np.mgrid[0:h, 0:w]
    fitted_surface = quad_surface((grid_x, grid_y), *params)

    depth_corrected = depth_component.astype(np.float32) - fitted_surface
    depth_corrected[body_corrected == 0] = 0
    return depth_corrected

# --- Rectification Tools ---
def get_pixel_boundaries(img: np.ndarray, mask: np.ndarray) -> np.ndarray:
    cnt, _ = cv2.findContours(image=mask, mode=cv2.RETR_EXTERNAL, method=cv2.CHAIN_APPROX_NONE)
    cnt = max(cnt, key=len)
    cnt = np.squeeze(cnt)
    pixels = np.swapaxes(img, axis1=0, axis2=1)
    pixels = pixels[tuple(cnt.T)]
    return np.expand_dims(pixels, axis=1)

def rectify_boundary_mask(img: np.ndarray, mask: np.ndarray, iterations: int = 100):
    pxl1 = get_pixel_boundaries(img, mask)
    h, w, *_ = pxl1.shape
    dilations = [pxl1]

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    temp = mask.copy()
    for _ in range(iterations):
        temp = cv2.dilate(temp, kernel, iterations=1)
        pxl = get_pixel_boundaries(img, temp)
        pxl = cv2.resize(pxl, dsize=(w, h), interpolation=cv2.INTER_CUBIC)
        dilations.append(pxl)

    temp = mask.copy()
    erosions = []
    for _ in range(iterations):
        temp = cv2.erode(temp, kernel, iterations=1)
        ncomp, _ = cv2.connectedComponents(temp)
        if ncomp > 2:
            break
        pxl = get_pixel_boundaries(img, temp)
        pxl = cv2.resize(pxl, dsize=(w, h), interpolation=cv2.INTER_CUBIC)
        erosions.append(pxl)

    rectify_img = np.hstack(erosions[::-1] + dilations)
    return rectify_img.transpose(1, 0) if img.ndim == 2 else rectify_img.transpose(1, 0, 2)

# --- Feature Extraction ---
def extract_profile_features(profile):
    mean_val = np.mean(profile)
    std_val = np.std(profile)
    min_val = np.min(profile)
    max_val = np.max(profile)
    range_val = max_val - min_val
    skewness = skew(profile)
    kurt = kurtosis(profile)

    slope = np.gradient(profile)
    max_slope = np.max(np.abs(slope))
    positions = np.arange(len(profile))
    center_of_mass = np.sum(positions * profile) / np.sum(profile)
    area = simpson(profile)

    fft_vals = np.abs(fft(profile))
    fft_features = fft_vals[1:11]  # skip DC

    return [
        mean_val, std_val, min_val, max_val, range_val,
        skewness, kurt, max_slope, center_of_mass, area
    ] + list(fft_features)

# --- Main Pipeline Entry Point ---
def process_single_wound(name, base_path="../data"):
    img, depth, wound, body = load_inputs(name, base_path)
    body_corrected, depth_component = filter_body_with_zscore(depth, body)
    depth_corrected = correct_depth_curvature(depth_component, wound, body_corrected)
    blurred_depth = cv2.GaussianBlur(depth_corrected.astype(np.float32), (5, 5), sigmaX=1)
    strip = rectify_boundary_mask(np.where(blurred_depth != 0, blurred_depth, np.nan), wound, iterations=100)
    mean_profile = np.nanmean(strip, axis=0)
    mean_profile_smooth = gaussian_filter1d(mean_profile, sigma=2)
    return extract_profile_features(mean_profile_smooth)

# %% [markdown]
# ## Extracting Image Names

# %%
import pandas as pd
import os

image_ids = [
    os.path.splitext(f)[0]
    for f in os.listdir("../data/wound_masks")
    if f.endswith(".png")
]
df = pd.DataFrame(image_ids, columns=["image_id"])
df.to_csv("image_index.csv", index=False)

# %% [markdown]
# ## Extracting Features Vectors from the Sample

# %%
import numpy as np
df = pd.read_csv("image_index.csv")
features_all = []
valid_ids = []

for name in df["image_id"]:
    try:
        features = process_single_wound(name, base_path="../data")

        # Skip feature vectors that are all NaNs
        if np.isnan(features).all():
            print(f"Skipped {name} — all features are NaN.")
            continue

        features_all.append(features)
        valid_ids.append(name)

    except Exception as e:
        print(f"Error with {name}: {e}")


feature_names = [
    "mean", "std", "min", "max", "range", "skewness", "kurtosis",
    "max_slope", "center_of_mass", "area"
] + [f"fft_{i}" for i in range(1, 11)]

features_df = pd.DataFrame(features_all, columns=feature_names)
features_df.insert(0, "image_id", valid_ids)

# Save only valid rows
features_df.to_csv("wound_features_clean.csv", index=False)
# Out:
# Error with -LzGpa0VPSMJr2F9rDCN.-LzGpeFMtDMDIZw91eP3.-MIYUwBw1GSWCJ3DThGw: Peri-lesion mask is empty, skipping curve fitting.
# Error with -
Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lrx03iZOOOLAa-r42SU.-Lrx3MUaNrl3AUTVxV2M.-Lrx3xadt4tdzZOy72JT: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Nh6Dkvq0QXVfD1CWrgu.-Nh6E-tvfh0lGlzQqTiS.-NjgAeXLnZjla3qhM72W: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LivscGJhM_bffA-hYoF.-Livsj1eSIV9BzurR4DV.-LplJs8p82oaij-yA77j: max() arg is an empty sequence
# Error with -Lhe7Rr0kRFC2_3jT8E0.-LheAo8bpBszgBWluPxz.-LhtO1NxgmHvxzDQBa9h: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NN6FWXPla7WDvph7QqJ.-NN6Fd67RsAwtNLknAVi.-NVnNSlIGeiE65lSe_lZ: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Li7Gw53VbA92RZ3ABZB.-MQparOJxbnYW_9CEOgq.-Mlt41IsHjXmmsECfJXe: max() arg is an empty sequence
# Error with -LzGpa0VPSMJr2F9rDCN.-LzGpeFMtDMDIZw91eP3.-LzGppPe0tqAPUw5xiTT: Peri-lesion mask is empty, skipping curve fitting.
# Skipped -MSWv5SlosprB_aFvJYo.-MSWvBf-YxK6MKxGIxhr.-MUmODPr17x4RAifzw3i — all features are NaN.
# Error with -LeGr5GgY30JbjHXHI69.-LeGrASzOiaSf8oHM-pF.-Lug7syELCslCQ91_ldP: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnRfNk8_xBNCpmbZq50.-LnRfczH56-Et4DkX85f.-LtZPHlNQg3meIItSF0k: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Liq_w4K5UDKsni46WKd.-LwSGCt2xK8sVctxmFPl.-M4TUIz3DM0tx5q4qXMn: max() arg is an empty sequence
# Error with -LoyElDz7n6jv9EmAMw8.-LoyEzohKY7MdkaYfB0S.-MyRPspXblbCiEtnlP-j: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LtTczccIARlFKnjmwwO.-LtTd54D8w10BNGTAMpI.-Lzg3GDaHzfXePn-rSXd: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnRUo67yQGOfr1rPlTl.-LnRUxW6mWYHxJOj728Y.-LrIrqacR6iATsiuP1oA: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lim3WQ1HgxKNt2gv-gq.-LoPVkl5RQwJ_xNnGErN.-LoPVuMNP7FcMr-N1uci: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LpbOamzRD1fsi-6au3R.-Mqmwm14EIfQ5cA19SXG.-NkykCojIZwgBD63SGQm: max() arg is an empty sequence
# Error with -LhdopYWKpTuugtVldDl.-LhdpBmtmCA9QN_693FS.-MZqgGTcHpvGqzF1Uv5A: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MjheQqracSXAqmsrYyg.-MjheaUwqmoQF6zafiJy.-NFNaP9sIlrcaZde-pRr: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MvNOnbh2Qh0ZTFU0LjI.-MvNP266F8UsEgWYnrZI.-NXj0AALHlx6VYdDNsrz: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NHOoZ70QpQM7um_M3XF.-NHOojxAH2u4qid1oHyr.-Na5cBakmCb69kvst_yp: max() arg is an empty sequence
# Error with -Ls0vWqwKtqtRpa_L2za.-Ls0vozTr55lwnboNsZj.-Ls0vtU4bg6IgnmHRbzR: Peri-lesion mask is empty, skipping curve fitting.
# Error with -N_DTD_h-6VB06_ZRfvE.-N_DTHwbAkQ5WU_piXFE.-N_DTk2lfGTR7115DgR-: max() arg is an empty sequence
# Error with -Mtlg88Wyn0rQ0IsxUX5.-MtlgAbdb_pjXdAR_KTh.-MzElPsOfn6QeQA4OHQZ: max() arg is an empty sequence
# Error with -N54AzlS6z-DZQk1eMev.-N54BKqvY1QfjuiNH0ab.-N7-aFCXlMnvbiJDm4t_: max() arg is an empty sequence
# Error with -LrNfos2Qf4gJ_EqWwnl.-LrNj_RGPameCn6ej9rI.-M7vIwHPSwC8PHMen_HM: Peri-lesion mask is empty, skipping curve fitting.
# Error with -
Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lj0Hf9ONQrex5fQ9zCP.-Lj0HqPI9HGjW-nJXgfu.-Lj0IEHPLxrtZMYz1nVd: max() arg is an empty sequence
# Error with -MlF2dyRab5LlgZSppgO.-MlF2j-cq87Xp7A29_NK.-MlF2w8joLkchVq8Wrkv: max() arg is an empty sequence
# Error with -M-Ob5KRYQxMWnU8wvlJ.-M-ObGpG413SKganVap0.-MJR4msiVZxpMaBMP1eT: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MGbvlKY7WplutU_cpvm.-MGbw4qzDu_iFy4wci2-.-MHFOPdlQEzk9Pin8Skm: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LrJ0yu2MQVIC9mmVQU5.-LrJ1-9N8CU-8pcr3S2o.-NHYXHBsJksSOPBUbpfd: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MvSiyhDd62RIL72l3NN.-NQZHTWZ1BVYmC9NQAd7.-NddMvEz7K6prnhXGaW4: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NZeZ7iw5nhrM9T1d-CJ.-NZeZFgaEEE-NZuxuhlw.-Nfz7vso8gEw8kL3KlCt: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lrx03iZOOOLAa-r42SU.-Lrx3MUaNrl3AUTVxV2M.-LvieTa3e-hWaBkomONS: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MHV02e1E_IyU-SnFFcB.-MHV41ZfXu89QkQkwOCr.-N3T6AsXW20xCBM9zFn7: max() arg is an empty sequence
# Error with -LjL053LDwz53ECJceWS.-Lo-r9zciba06Hi4D04j.-MmHzkOlh49PECiEaxrU: max() arg is an empty sequence
# Error with -NOiQ_PBg4IJ2bJlRlEw.-NOiQe8JNQhZoDvw3lMA.-NW6TBv71hvWAMtMnDKh: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LcdxOOQmPqhJ1sa7orl.-LcdxgVUmgaYdaCUC-Uo.-Lcdxp411aQrC7QYkK7S: max() arg is an empty sequence
# Error with -Lulbc87BHgXQt7DhxtO.-M775ytwv7p3CNAXqaje.-MOVTHqRHnZWNhI3r4u3: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LpbOamzRD1fsi-6au3R.-Mqmwm14EIfQ5cA19SXG.-NU66zHnywAWPxFeJ0gA: max() arg is an empty sequence
# Error with -NM8EetnJRlrzdc7EdlE.-NM8EjpD18R0iW6Li8nF.-NUzBijm0NdqX5qUJQwx: max() arg is an empty sequence
# Error with -MzJP6qhOf8I5r38QOGy.-MzJPFkskaLDk03IbXto.-MzJPjM9d4xmSsLPighF: max() arg is an empty sequence
# Error with -Lo-ZdmJv-0kZM8lyXUX.-Lo-Zkh6JwG9iAYZb3U7.-Lpc25VhgycmWKdC-mBK: max() arg is an empty sequence
# Error with -NakRixzKnhdquFaDgBC.-NakS32j9Xi5OWyWwB40.-NakS7g6f3q4_1g7O_gn: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnqBPug1s3pitse4L_2.-LnqBq7-bjk7zKZyhgbp.-LnqBzOAPWHmbtLqv3zD: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LoZeQLFYyoDyTlTKZ3B.-LoZeYLD7hrroOGm7BR7.-M89l3OrSRWyr4BaPe7t: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LoxpvK6DFelBYkfy86-.-Loxq81ZRRlzceTQOJ6-.-LoxqvUHIDzLC5bhLT7w: max() arg is an empty sequence
# Error with -Lh_0X8azL7oNLfGmyxy.-Lh_0eZcnJ3VIDLJ_nSJ.-LoJemy0OO15H3GE3Yrp: Peri-lesion mask is empty, skipping curve fitting.
# Error with -N2L5E4vNd0BYiMZcEJi.-N2L5K0vZP35WS4HIpqr.-NXngywlgGhQxcGbiu_G: max() arg is an empty sequence
# Error with -LeGr5GgY30JbjHXHI69.-LeGrASzOiaSf8oHM-pF.-MXf7ouyfYr0pho9sdSB: Peri-lesion mask is empty, skipping curve fitting.
# Error with -McDMFkpooGzi_FyySuv.-McDMciz3MbirxQJ6g5w.-MlEfi-eUUm3GS09ockh: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MGmIKezRNv91cu4cc3y.-MGmIRh9qKurbO_epW9M.-MGmIfW517-eyCSSRT43: max() arg is an empty sequence
# Error with -LkxK1hw4N6XYpid0sKT.-LkxLZAUPGqJfS7DG1od.-N6N1Q8uh14_-2CWr2UL: Peri-lesion mask is empty, skipping curve fitting.
# Error with -N3T3J22UG6-6qz3L24S.-N5dwYgdkwoZ6EwDqX_d.-NEoNZiAnvkiGR1bH0Kk: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NEFcK1eOZxEueauYWOP.-NEFcUU5oyHjqVWhiW0v.-NNGFU5D_3cyUT0EqWRc: max() arg is an empty sequence
# Error with -Lhj8_OP_d9ivL6xWFma.-Lhj8irY_c62oBCqWYx6.-LlGbq08Sxf8t9feCplY: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LimCEPj4cm8u6UaR3tY.-Lq5kl7IDH9h8Q9cfZx7.-MoItaeQXsHLIngzGSTO: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Li7Gw53VbA92RZ3ABZB.-M-nnzs_CQxmNYcgiTb-.-MgFcExUdmH2XjPVjehT: max() arg is an empty sequence
# Error with -LjGBIYnULLBckx6_33e.-LjGBSWiBH-PwIJV_e8T.-MpQI5zEAb6tROU7sfcx: max() arg is an empty sequence
# Error with -LeLARl6cYWbEMnS6aOi.-LeLAYdDy8QM1wwAqCtg.-LkNYqJ14a3ysyjiU_jF: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MHpXA9l-8jNikbWEcCd.-MHpXeXMl9rrBPRzM_ai.-MKdlmboPvlj42Ouw3aU: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LigWgu5Phrzy984n4_1.-LigWt34wKvEslEHvqqR.-Lig_-HNmT9ckQjj-XrS: Peri-lesion mask is empty, skipping curve fitting.
# Skipped -MvIKo8-hZezc4rytLP3.-MvIKzHuny73dT_i3PyL.-MxmiPBo9K_JDIIb_Vqs — all features are NaN.
# Error with -Mkkq-BYie-_L1cjH_kn.-Mp66-pOmG5KYvXGCzhV.-MyHA9u8HGCcff7zFyOO: max() arg is an empty sequence
# Error with -Lnq8NzVJiNNcpm3l4nX.-Lnq8eD1KV60FdOxNFXG.-LnqKcTnECn_ScZ061NU: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MHocsSpEtlFbqNEl9k8.-MHodn65eYzkDRK_pN7q.-MHoe6PJWCnqDgR_3BoU: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Ligllbm3stnvnxyfJQD.-LigltRUcTjCgj7JmjNE.-LigmkEG_2EWwe6-rGVK: max() arg is an empty sequence
# Error with -M9MuTD0_-xs4PVoSDav.-MG2x4HmCmylHx7mX_f0.-MJBra5LiGofNmO0YWOc: max() arg is an empty sequence
# Error with -MVGO1f8JZm1DWnxjxEa.-MVGOG2Q9CEta12viF7V.-Mc8NQZbo4FVZeZxh_ht: Peri-lesion mask is empty, skipping curve fitting.
# ...
# Error with -N05Ap9ymdkMzonhjWtA.-N05DpgHUVyik-ZB5Liy.-N703u3j_XdkZes2z7Xq: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LeLiaV_6NrLdFlMbLi_.-LiCBvXce-5OzfiYh1Tu.-M2ljNWaiqIoct2ZZHtD: Peri-lesion mask is empty, skipping curve fitting.
# Error with -M77E9GmMP_x69tZBC53.-M77FOIJh4okcvlA-yMP.-MCQPf6O4Wg5rF99Y-yl: max() arg is an empty sequence
# Skipped -MIOBNUgcr0MTphTegMf.-NQA8fKMThwrY9iaWqfh.-NiZR2X3_R6cy6hDyUdC — all features are NaN.
# Error with -NYbRMT2qkWA2bYT9ZGm.-NYbRkv8Flb2zjo4PsN4.-NeMtJgZD9EqZoOUFHug: axis 1 is out of bounds for array of dimension 1
# Error with -Mk6F7_DicTF4xbi_qpF.-Mk6FF692moQKRKjR5FI.-MqEWX4fuSd5rQOoh7EM: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MoDN_J5LBr83wffr7fM.-MoDNsQSyA-FrWZBXWMk.-MoDODyvF2x52NlcMPGx: max() arg is an empty sequence
# Error with -N2jwJv8wuACnp4w0m7p.-N2jwSNWiPdiKArtj4TY.-N6RVUsB6yRCw9itLEqd: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MzFA6p_f87DJrGlFd-x.-MzFAEe1hCSuILT2cNKL.-MzFBYBzcZH4qK6aBVXW: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NC-DFTC_C5Sl12U1ygl.-NC-DLxrFnu5ORGIzLLY.-NC-DQ6bmCsLRfEGc_8I: max() arg is an empty sequence
# Error with -LwSkFLpVhoo06-eXQDi.-MOeeZjl7tw6PvuJscuD.-MYiUbXlMzaEksFng2v9: max() arg is an empty sequence
# Error with -Liq_w4K5UDKsni46WKd.-Liqa7QMEVYvlAPfvU60.-LiqaLY00QX5cpKyep4i: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MT-fuAMSOtqOYpbrBt0.-MT-ivaRbI9JRvYR1-_-.-MZCWTqxnUwZx-T5yEmz: max() arg is an empty sequence
# Error with -LnRUo67yQGOfr1rPlTl.-LnRUxW6mWYHxJOj728Y.-MMKutRd-s1oXPsWy7xx: max() arg is an empty sequence
# Error with -LhdFLzW3R4slzUTPMJv.-LhdFCZ-nAprdI05MSMp.-LwNQRi_zo_oJNt0jtVy: Peri-lesion mask is empty, skipping curve fitting.
# Error with -M-OnrHA0wmu3ymvKWA8.-M-Oo9RqHfWyjRggeAS9.-MNN0bp_56bfHGPFgUiL: max() arg is an empty sequence
# Error with -NOiQ_PBg4IJ2bJlRlEw.-NOiQnYIWvtWCjhPG9DG.-NW6TObFpp_DAzc4sQ2l: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LjFKsmhNs3onX0XxZUu.-LjFKxpB1jZQHBZ9FpdT.-M6nNq_s_F6SnITANSWs: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LymcSeEKDNlZFwBbnSW.-LymcWkRpDZtVaOTqWrs.-M02A5R--jD4cBKXpAez: max() arg is an empty sequence
# Error with -Njv6RIxzakfSoFvCJul.-Njv6WM9cLpD75AT5VVm.-Njv6cpHmHvJa1yzM1En: max() arg is an empty sequence
# Error with -LimCEPj4cm8u6UaR3tY.-Lq5kl7IDH9h8Q9cfZx7.-MuG1rXVT47jdeQCi7IA: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Mj8A5WiZkzJQPQZHUxX.-N1wWLe-imNjHY0ey97h.-NQPOyY81djnnI-kfSAx: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NCZhA108X9efhCMkWpz.-NCZhRJLlvkted9DF7PN.-NFwyeUdyMEDZykGrbkO: max() arg is an empty sequence
# Error with -MwzJf4-bHEoLw4GxVtj.-MwzK_ZPonLEHeGnfzI-.-N7ZqGGubx4tgpNqX5Fs: max() arg is an empty sequence
# Error with -LnRUo67yQGOfr1rPlTl.-LnRV1KUjTGqgvA7Sow7.-MMKuo4YQgx6S24xmL8v: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NeMreqmG_AJT3wdYmIR.-NeqRuq3eZpjTv6ZPvVS.-NgT7n7M64pB0EQ7zQLh: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnlUXRYaeGwFh4MYHi2.-Lq_HQgWb79UPTAD5eBU.-Lq_HWWA-LYlY9Axmtdg: max() arg is an empty sequence
# Error with -M3G5Qopdq7sBLOsoi6T.-M3G5WvdGe-IjRMW_MC7.-M3G5wgtsIiX7oG4VHSp: max() arg is an empty sequence
# Error with -MAZwkBlqAfwZSw-f8pt.-MAZwp1JsTM5b0WUZ4c1.-MwVP1V6v8G3lN3L20KN: max() arg is an empty sequence
# Error with -Li7Gw53VbA92RZ3ABZB.-Li7HAzKrOiI0a1m1y0I.-MIc2xofCu0W4-769gHF: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Li7Gw53VbA92RZ3ABZB.-N1glgPSQZYOfWaU9QbV.-NGzKYupyDovJ82oFlaW: max() arg is an empty sequence
# Error with -Lj_Qd4twBBGwBtgQAE9.-NLP_uf1wj_ZkwCtN2QJ.-NddjbmmSHnxWxpJ6IPM: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MGI5uSxXZQXkms2705g.-MGI6C6z3Q4zgG15cG3R.-N6gGofwEQuR2Ax-t7oT: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MkLlrfZmfg03DWwgdr5.-MkLm093DMb_W-V1yUXZ.-N5-P_HrHa1S2NbIRh39: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LpbOamzRD1fsi-6au3R.-LpbOyQHxj0L0e7PEi-I.-M9S7A6a4Vjf3zG3rf-Y: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Mr6c-LXbxozsrh9gPz0.-Mr6cB0LIvAyCvUSpfOK.-NKMwn9QMYdsAGbgzYoj: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LkSxgdWu3mrv0klTuuT.-LkSxq8ao9-5yLS9f5xw.-MzExwRWGNfD7FcD3tcb: max() arg is an empty sequence
# Error with -MqJ8RHnrbz8Xti1wHHb.-MqJ8bJaFrchCnNhkMlW.-MtlLN1ul83vH42UULcj: max() arg is an empty sequence
# Error with -MK3thYUGilXbhGZ19HG.-MR3xL1DUPB5-Hw_IBxb.-MUSFHQK-uMuyTQO6yCQ: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Liq_w4K5UDKsni46WKd.-Liqa7QMEVYvlAPfvU60.-LwSGOE0jlif_tRA2mX4: max() arg is an empty sequence
# Error with -Lrx03iZOOOLAa-r42SU.-Lrx3MUaNrl3AUTVxV2M.-Lrx3rUFOL2LvvAjcV9Q: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LceKoJLHb8IoImrI10u.-LrNOtXG02hKNrPDBMR0.-MgKDirCwHMIrBbppGp4: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NKqt26V9R-mBxkxU81X.-NMTOj7ybvg-VPbg9Tmz.-NNB3GE-PHVL0SA7eAzL: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Mr1XNDk2MP8cAsGvHca.-Mr1X_f-Zk3BoK3QLw73.-NIbGV405-TKnbWAJllI: max() arg is an empty sequence
# Error with -N41Ar9Thas5h4Ej5Y0A.-N41B-__trAhjtC6Klye.-N41B5i0V4zMuPsl7WDm: Peri-lesion mask is empty, skipping curve fitting.
# Error with -
Peri-lesion mask is empty, skipping curve fitting.
# Error with -Ly8g-CAAjH52tNpgDLJ.-Ly8g5F7hbrd5X0DBzIL.-M4wd5GdhPHn0bPG3BE2: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnpiWnbjpXynctDwoU3.-LnpiajgPwSQtok5EPVL.-LulTrfVHSoydkAxNiZE: max() arg is an empty sequence
# Error with -LceKoJLHb8IoImrI10u.-LnCM3vwNpIsMhOoOzDc.-MUSMdYo6C83F5QQTfe5: max() arg is an empty sequence
# Error with -LiMpCaA24H9MjEXOVk0.-LiMpKyjdotKO7FGl0BA.-Lrmf2bFS9RLEnFxd-Cx: Peri-lesion mask is empty, skipping curve fitting.
# Error with -McE1oz7o-gH5vQsbCKZ.-MhHuwOgM3rZjVKM2Uo-.-MhHv-yulZLyedRCLDZq: max() arg is an empty sequence
# Error with -McDMFkpooGzi_FyySuv.-McDMciz3MbirxQJ6g5w.-N4l7NoAgXwkqtEZEY13: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LhdopYWKpTuugtVldDl.-LhdpBmtmCA9QN_693FS.-LwNt_gEoDt8DTwPG6MD: max() arg is an empty sequence
# Error with -Lpb4l4JaXOMbKBkV1QN.-Lpb5-zaezaBKm5FZCiW.-LulXP0lak_roAlh_9qb: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NPaxlJRSCtemhF3ouVD.-NPayKPdMatJ5z4hxTxJ.-NPayY_Mdi_QuO8eYi9G: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LrhBSuIfKjLrRNU1zx5.-LrhBVBpGovjg5cY5hvm.-LrhB_95OCUtriLgkApI: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lulbc87BHgXQt7DhxtO.-MOVTYX2_kmeRkAPko9N.-Mb_RfYbEzrOUICEMulz: max() arg is an empty sequence
# Error with -Lv9wq5OznXqxb6GWUhi.-Lv9xwcFWNm_0m54vowT.-Lyc90dN1pB8jGBG6j_k: axis 1 is out of bounds for array of dimension 1
# Error with -LimCEPj4cm8u6UaR3tY.-Lq5kl7IDH9h8Q9cfZx7.-MoItUxQac0ChmRlq66N: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MpLAIls3c9Zt-aRzUug.-MpLAPDSOhSb9nepHRRt.-MzJpRcsW5eZdm6KSENu: max() arg is an empty sequence
# Error with -LkxK1hw4N6XYpid0sKT.-LkxLZAUPGqJfS7DG1od.-LkxLry7SPrOTSkXJfGD: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lim3WQ1HgxKNt2gv-gq.-LoPVkl5RQwJ_xNnGErN.-LsWUmvi6qrums7UCvVT: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnGiDGrlmz9FvHsGg3w.-LnGiLl-FO12TPN7P6Z9.-LvKgrE4Byj_jM98GWih: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LhsorPQ__UewrB6Zqeu.-Lhsp5KOfiR-ngijzg2c.-Lossml4q8gUNTCd3kN-: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LhdopYWKpTuugtVldDl.-LhdpTOZKIN0FHOQEbM_.-LwNtiGjYTN9HM4kbxPC: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MIcBKOd_tnLAszxkFon.-MIcBjVT8RGd_73zNO7L.-MNcQNygAOKgb4AiCQlg: max() arg is an empty sequence
# Error with -MIOBNUgcr0MTphTegMf.-MIOBUH4T6I0shR6OuD-.-Mc8f_UNf4Q4MAjNcsl8: max() arg is an empty sequence
# Error with -MXfL6xiimGibxc-mHXj.-MXfLJaxihJHWGBGd5Jj.-MiUzwtxfE4qlsdLyO4n: Peri-lesion mask is empty, skipping curve fitting.
# Error with -N3OD3cQEpn8dcof4kFk.-N3OD7snKhCeu4udRypL.-N3ODIQy3mEPV0qntEi_: max() arg is an empty sequence
# Error with -NG_v-quK1IzNNsiAGZP.-NG_v93QEWhwTan--6yi.-NYHuerK11JZfCoWix45: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MLRgdtT6JDiojBPUUas.-MLRglSL64oTsI-bDC0H.-MYEeRTJXdBlKsl8Nbbt: max() arg is an empty sequence
# Error with -Mbf1QJ_W0ZPQdl1-jdq.-Mbf1h2zD0ujPpOXA__8.-MdVidhasNhFozkUwUVC: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LrmRd8IxEdBn2j-F8ht.-LrmTKkBTjJFpAoZ3oF_.-MOGIabZHU0JxgE8ezHM: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LiwBy8_gwK2dqZULgoM.-LiwC3rnu9aohR3JDpNu.-LpXYhcbhMRldXxASQGo: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LoUS5Uc44f3SRsF9Yhh.-LoUSBmG4GlQ7K7Cq1xa.-LoUSPpWb986noQMr0QL: max() arg is an empty sequence
# Error with -N4ktWo4jeNSf4X-x7nv.-N4ku3gzVaRT3wnth0Wj.-N4kuH6_jH8OLSUvynuf: max() arg is an empty sequence
# Error with -NPMVfVy4CaAWAFUdggK.-NYX3z4KhNAvvB3VBxRu.-NYX44QwnEIkF4bdsjKB: max() arg is an empty sequence
# Error with -LiIBt756NWTxFehxE_y.-LiIC-w4RI19D7Mus8PE.-LiICDsbUAfJmMu6wZbd: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lim3WQ1HgxKNt2gv-gq.-LoPVkl5RQwJ_xNnGErN.-M15QH6Km-NRjUzi010x: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LwDIOlM_-SoOdQMs-01.-MmbIP19Z3GImJzl_hcX.-NEj_vSr61tuVSHSJeZX: max() arg is an empty sequence
# Error with -MvSiyhDd62RIL72l3NN.-NQZHQ_EoHdrihuh9PPq.-NddNL9GQC7HakWFW2Px: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LeGaSjy77PPaRP_E_OB.-LyYCC5LH0yG9b9tQMak.-LyYCFqeOyx5Il7kLdrU: max() arg is an empty sequence
# Error with -LoUCzWmWVAQSXuE9BDs.-LoUDGiNfE_GkmzIRw7p.-LveWDYzihvwzVtdmag6: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MkLlrfZmfg03DWwgdr5.-MkLm093DMb_W-V1yUXZ.-MvrrqFnXoGYoJQOYhlI: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LimCEPj4cm8u6UaR3tY.-Lq5kl7IDH9h8Q9cfZx7.-NLeqgyGDGd48TFTnWVE: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LceeaNQDdA2VnD6w5EO.-LiCukCzxGlg8mFGYDs0.-LvoYMVpR_ZdmiczBhni: Peri-lesion mask is empty, skipping curve fitting.
# Error with -M-Ob5KRYQxMWnU8wvlJ.-M-ObGpG413SKganVap0.-MNhGu-uKt15Bc1dzJ2W: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LrNfos2Qf4gJ_EqWwnl.-LrNjgmKUw1NmKC61QHM.-LrNpRPEasCvFu6l-zxY: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LiwHS89iphwTuLVEkcv.-NXiTvc2kBlWon5DWpwb.-NfjaLw9CTfKC6nTVt6f: Peri-lesion mask is empty, skipping curve fitting.
# Error with -M1_651WDbXXvq_7CjHn.-M1_6LODNncldOkRWH7o.-MA0g6X-A-9E-HBk0qqA: axis 1 is out of bounds for array of dimension 1
# Error with -N2L5E4vNd0BYiMZcEJi.-N8XaZmEkTa64ZLUpWw-.-NXngqm3hjvnrjyihZrF: Peri-lesion mask is empty, skipping curve fitting.
# Error with -MnjJ9ac7flEVJpQToLb.-MnjJIF1eFqszyYWauCG.-Mwzq0FkF98rcWzVhPHt: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lz6SwQH8reQ0uyXOfnG.-Lz6T1rcRbztWSxrk68I.-M9XrHB8A-B7VIATINi_: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lhdg-8NYK9J1sR8F-30.-Lhdg70Xtas2-Gv0sG4G.-Lull6RuyMPci0d4Tmnr: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LrDXcfG0ictUj05_cTn.-LrDXoX9ND9OP7OO0sUW.-LtUDxa3o0WVTc_5Ku47: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnlKFv4p1g71rkiw4cz.-LnlKOWptXrFjqgXvxHK.-LnlKegcAdsHp3G1EdLz: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lp7PUyQTrv7lON9UkZp.-Lp7PdRdtEXPgXxz2IoA.-LsRB6wabbDNrb6oKAmP: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Lh_4fCwSuZCptBWsQEL.-Lh_4qpE43YfcambEOhH.-LyEGuJE465bK519HLai: max() arg is an empty sequence
# Error with -NOEY1KbehbvKt3DY1s1.-NOEYhtaDYEMGepf8zYA.-NOEYkbsqnnTzO9Do6GD: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LhiNil_EXKtQG_TFjMS.-LhiO8wS4LfvTj5u4p86.-LhiOIaroK7H5DPF-ZOv: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NOiQ_PBg4IJ2bJlRlEw.-NOiRAnmFzLLsWQ2GuNP.-NW6TH6Z2h--9eNQSR2s: max() arg is an empty sequence
# Error with -MV_eMOGc0k97o1PyIQW.-MV_eSuIz1N8Xz_w1o-J.-Md_rqZsOUri2sZPX0iT: max() arg is an empty sequence
# Error with -LiI9MWE6_hhHCGU-Z6W.-Lpb_lUnQUbgrwsT35nD.-LuaUs-0IBAA2stlZZ7y: Peri-lesion mask is empty, skipping curve fitting.
# Error with -Ly8g-CAAjH52tNpgDLJ.-Ly8g2RJxRLQlQZ9JlNY.-M4wcxwdk4d4YgPsrKEm: Peri-lesion mask is empty, skipping curve fitting.
# Error with -NEjH4H3wlUfzclWWMcB.-NLVGI7iVaYrh30YZeTu.-NLVGTLVMzhgj1BWfnmU: max() arg is an empty sequence
# Error with -Li78_-q6o1fQuak5tjs.-Lrm016ZmvchzFBoLkE-.-LuBgiP7Npju5jr5GVUp: Peri-lesion mask is empty, skipping curve fitting.
# Error with -LnvJOiOC0hyFobuXd5Z.-LnvJTU9-J1J_3OpDavY.-Lsuu9nXPPHKtfymklFs: max() arg is an empty sequence
# Error with -MrzuDOoU2f3mnIX14KY.-MrzuJjGz4SP9p3X7LNd.-MxmxDEcnDvCuRyrtM3d: max() arg is an empty sequence
# Error with -MlncCIzfvXlSdE6UGOX.-MlncJ6aZgLuy5QVF6mv.-NJt7QtUQTiF0p1nVWoi: max() arg is an empty sequence
# Error with -Moc0BVPVOr60FcVWR7b.-Moc11UxCWGpI4RjYHx2.-MxYqfTuS_FluEJfnOE_: Peri-lesion mask is empty, skipping curve fitting.
# Error with -McDf4jGs9jNwsTucDep.-McDfDZXsX_zGPQhdT9u.-MhHmZINkEOynsTHgPEX: Peri-lesion mask is empty, skipping curve fitting.
